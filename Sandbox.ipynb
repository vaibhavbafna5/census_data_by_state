# %%
from census import Census
import us
import requests
import pandas as pd

# TODO: should put this as an env variable (despite US Census mysteriously emailing around their API keys)
API_KEY = 'b3429317418aab0b6f375290db2a3420535d135c'

# %%
def generate_survey_codes_for_each_state():
    """
    A true beast of a function. Takes more LOC than hardcoding. 
    """
    codes = []
    for i in range(ord('A'), ord('I') + 1):
        letter = str.upper(chr(i))
        full_code = f'B01001{letter}'
        codes.append(full_code)
    
    codes
    return codes

# %%
def get_variable_names_to_labels_mapping(full_variables):
    """    
    full_variables : List[str] - list of full variables (e.g. ['B01001A_001E', 'B01001A_002E'])
    
    returns a mapping of inscrutable Census code --> CONCEPT + LABEL (e.g. 
    
    ~approach partly ripped from code here --> shorturl.at/bkLOP.
    """
    
    variables_to_labels = {}
    
    for full_variable in full_variables:
        variable_table_url = f'https://api.census.gov/data/2017/acs/acs5/variables/{full_variable}.html'
        v_table = pd.read_html(variable_table_url)
        variable_df = pd.DataFrame(v_table[0])
        variable_df['Label'].replace({"!!": " ", ":": ""}, regex=True, inplace=True)
        
        variables_to_labels[full_variable] = variable_df.iloc[0]['Concept'] + " " + variable_df.iloc[0]['Label']
        
        
    return variables_to_labels

# %%
def get_data_by_group_and_state(group, state):
    """
    group : str - group level tag (e.g. B01001A)
    state : str - number representation of a state (e.g. 01 --> Alabama)
    
    returns a dict (e.g. B01001A_001E --> 864,675)
    """
    url = f'https://api.census.gov/data/2021/acs/acs1?get=group({group})&for=state:{state}'
    r = requests.get(url)
    r_json = r.json()

    variables_to_values = dict(zip(r_json[0][:-3], r_json[1][:-3]))
    variables_to_values = {k:v for k,v in variables_to_values.items() if v != None} 
            
    return variables_to_values

# %%
state_fips = [state.fips for state in us.states.STATES]
survey_codes = generate_survey_codes_for_each_state()
    
state_to_population_data = {}

# %%
group_survey_code = 'B01001A'
state_fip = '01'

state_data = get_data_by_group_and_state(group_survey_code, state_fip)
state_data
# Out:
# {'B01001A_001E': '3281881',
#  'B01001A_001M': '9108',
#  'B01001A_002E': '1609702',
#  'B01001A_002M': '5390',
#  'B01001A_003E': '83827',
#  'B01001A_003M': '1539',
#  'B01001A_004E': '88219',
#  'B01001A_004M': '3229',
#  'B01001A_005E': '99071',
#  'B01001A_005M': '3419',
#  'B01001A_006E': '61015',
#  'B01001A_006M': '1917',
#  'B01001A_007E': '39245',
#  'B01001A_007M': '2082',
#  'B01001A_008E': '99922',
#  'B01001A_008M': '2494',
#  'B01001A_009E': '97794',
#  'B01001A_009M': '1740',
#  'B01001A_010E': '99019',
#  'B01001A_010M': '2052',
#  'B01001A_011E': '200941',
#  'B01001A_011M': '2313',
#  'B01001A_012E': '206146',
#  'B01001A_012M': '2016',
#  'B01001A_013E': '232671',
#  'B01001A_013M': '1233',
#  'B01001A_014E': '188404',
#  'B01001A_014M': '889',
#  'B01001A_015E': '90312',
#  'B01001A_015M': '1896',
#  'B01001A_016E': '23116',
#  'B01001A_016M': '1883',
#  'B01001A_017E': '1672179',
#  'B01001A_017M': '6167',
#  'B01001A_018E': '79300',
#  'B01001A_018M': '2504',
#  'B01001A_019E': '85043',
#  'B01001A_019M': '4437',
#  'B01001A_020E': '97231',
#  'B01001A_020M': '3974',
#  'B01001A_021E': '57671',
#  'B01001A_021M': '1563',
#  'B01001A_022E': '40350',
#  'B01001A_022M': '2181',
#  'B01001A_023E': '97109',
#  'B01001A_023M': '2670',
#  'B01001A_024E': '96672',
#  'B01001A_024M': '2016',
#  'B01001A_025E': '100822',
#  'B01001A_025M': '1973',
#  'B01001A_026E': '201884',
#  'B01001A_026M': '2521',
#  'B01001A_027E': '208286',
#  'B01001A_027M': '1654',
#  'B01001A_028E': '239333',
#  'B01001A_028M': '1051',
#  'B01001A_029E': '209681',
#  'B01001A_029M': '1014',
#  'B01001A_030E': '117099',
#  'B01001A_030M': '3055',
#  'B01001A_031E': '41698',
#  'B01001A_031M': '2943'}

# %%
state_variables = list(state_data.keys())
state_variables
# Out:
# ['B01001A_001E',
#  'B01001A_001M',
#  'B01001A_002E',
#  'B01001A_002M',
#  'B01001A_003E',
#  'B01001A_003M',
#  'B01001A_004E',
#  'B01001A_004M',
#  'B01001A_005E',
#  'B01001A_005M',
#  'B01001A_006E',
#  'B01001A_006M',
#  'B01001A_007E',
#  'B01001A_007M',
#  'B01001A_008E',
#  'B01001A_008M',
#  'B01001A_009E',
#  'B01001A_009M',
#  'B01001A_010E',
#  'B01001A_010M',
#  'B01001A_011E',
#  'B01001A_011M',
#  'B01001A_012E',
#  'B01001A_012M',
#  'B01001A_013E',
#  'B01001A_013M',
#  'B01001A_014E',
#  'B01001A_014M',
#  'B01001A_015E',
#  'B01001A_015M',
#  'B01001A_016E',
#  'B01001A_016M',
#  'B01001A_017E',
#  'B01001A_017M',
#  'B01001A_018E',
#  'B01001A_018M',
#  'B01001A_019E',
#  'B01001A_019M',
#  'B01001A_020E',
#  'B01001A_020M',
#  'B01001A_021E',
#  'B01001A_021M',
#  'B01001A_022E',
#  'B01001A_022M',
#  'B01001A_023E',
#  'B01001A_023M',
#  'B01001A_024E',
#  'B01001A_024M',
#  'B01001A_025E',
#  'B01001A_025M',
#  'B01001A_026E',
#  'B01001A_026M',
#  'B01001A_027E',
#  'B01001A_027M',
#  'B01001A_028E',
#  'B01001A_028M',
#  'B01001A_029E',
#  'B01001A_029M',
#  'B01001A_030E',
#  'B01001A_030M',
#  'B01001A_031E',
#  'B01001A_031M']

# %%
state_variable_names_to_labels = get_variable_names_to_labels_mapping(state_variables)
state_variable_names_to_labels
# Out:
# {'B01001A_001E': 'SEX BY AGE (WHITE ALONE) Estimate Total',
#  'B01001A_001M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total',
#  'B01001A_002E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male',
#  'B01001A_002M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male',
#  'B01001A_003E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male Under 5 years',
#  'B01001A_003M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male Under 5 years',
#  'B01001A_004E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 5 to 9 years',
#  'B01001A_004M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 5 to 9 years',
#  'B01001A_005E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 10 to 14 years',
#  'B01001A_005M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 10 to 14 years',
#  'B01001A_006E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 15 to 17 years',
#  'B01001A_006M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 15 to 17 years',
#  'B01001A_007E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 18 and 19 years',
#  'B01001A_007M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 18 and 19 years',
#  'B01001A_008E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 20 to 24 years',
#  'B01001A_008M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 20 to 24 years',
#  'B01001A_009E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 25 to 29 years',
#  'B01001A_009M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 25 to 29 years',
#  'B01001A_010E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 30 to 34 years',
#  'B01001A_010M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 30 to 34 years',
#  'B01001A_011E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 35 to 44 years',
#  'B01001A_011M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 35 to 44 years',
#  'B01001A_012E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 45 to 54 years',
#  'B01001A_012M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 45 to 54 years',
#  'B01001A_013E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 55 to 64 years',
#  'B01001A_013M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 55 to 64 years',
#  'B01001A_014E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 65 to 74 years',
#  'B01001A_014M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 65 to 74 years',
#  'B01001A_015E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 75 to 84 years',
#  'B01001A_015M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 75 to 84 years',
#  'B01001A_016E': 'SEX BY AGE (WHITE ALONE) Estimate Total Male 85 years and over',
#  'B01001A_016M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 85 years and over',
#  'B01001A_017E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female',
#  'B01001A_017M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female',
#  'B01001A_018E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female Under 5 years',
#  'B01001A_018M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female Under 5 years',
#  'B01001A_019E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 5 to 9 years',
#  'B01001A_019M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 5 to 9 years',
#  'B01001A_020E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 10 to 14 years',
#  'B01001A_020M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 10 to 14 years',
#  'B01001A_021E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 15 to 17 years',
#  'B01001A_021M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 15 to 17 years',
#  'B01001A_022E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 18 and 19 years',
#  'B01001A_022M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 18 and 19 years',
#  'B01001A_023E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 20 to 24 years',
#  'B01001A_023M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 20 to 24 years',
#  'B01001A_024E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 25 to 29 years',
#  'B01001A_024M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 25 to 29 years',
#  'B01001A_025E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 30 to 34 years',
#  'B01001A_025M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 30 to 34 years',
#  'B01001A_026E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 35 to 44 years',
#  'B01001A_026M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 35 to 44 years',
#  'B01001A_027E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 45 to 54 years',
#  'B01001A_027M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 45 to 54 years',
#  'B01001A_028E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 55 to 64 years',
#  'B01001A_028M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 55 to 64 years',
#  'B01001A_029E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 65 to 74 years',
#  'B01001A_029M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 65 to 74 years',
#  'B01001A_030E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 75 to 84 years',
#  'B01001A_030M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 75 to 84 years',
#  'B01001A_031E': 'SEX BY AGE (WHITE ALONE) Estimate Total Female 85 years and over',
#  'B01001A_031M': 'SEX BY AGE (WHITE ALONE) Margin of Error Total Female 85 years and over'}

# %%
state_df = pd.DataFrame(columns=['FULL_VARIABLE', 'CONCEPT', 'VALUE'])

pd.option_context('display.max_rows', None, 'display.max_columns', None,)

for variable, value in state_data.items():
    concept = state_variable_names_to_labels[variable]
    row = {
        'FULL_VARIABLE' : variable, 
        'CONCEPT' : concept,
        'VALUE' : value
    }
    state_df = state_df.append(row, ignore_index=True)
# Out:
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/175342160.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   state_df = state_df.append(row, ignore_index=True)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

state_df.head(65)

total = 0
labels = []

for i in range(2, 32):
    value = state_df.iloc[i]['VALUE']
    concept = state_df.iloc[i]['CONCEPT']
    
    if 'Total' in concept:
        labels.append(concept)
        total += int(value)

total
# Out:
# /var/folders/vr/z_5vwbpd1_g_yt7p238qf3780000gn/T/ipykernel_55665/628076992.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# 3253496

# %%
labels
# Out:
# ['SEX BY AGE (WHITE ALONE) Estimate Total Male',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male Under 5 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male Under 5 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 5 to 9 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 5 to 9 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 10 to 14 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 10 to 14 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 15 to 17 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 15 to 17 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 18 and 19 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 18 and 19 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 20 to 24 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 20 to 24 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 25 to 29 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 25 to 29 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 30 to 34 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 30 to 34 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 35 to 44 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 35 to 44 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 45 to 54 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 45 to 54 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 55 to 64 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 55 to 64 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 65 to 74 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 65 to 74 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 75 to 84 years',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 75 to 84 years',
#  'SEX BY AGE (WHITE ALONE) Estimate Total Male 85 years and over',
#  'SEX BY AGE (WHITE ALONE) Margin of Error Total Male 85 years and over']

# %%
state_df.head(65)
state_df.to_csv('Alabama.csv', index=False)
